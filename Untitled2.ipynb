# %%
print(f"知识库共 {len(ra.CHUNKS)} 块")
# Out:
# 知识库共 89 块

# %%
print(ra.CHUNKS[0]["text"][:200])
# Out:
# 当您的中信银行信用卡成功批核后，我们将以邮寄（挂号信或EMS） 的方式将实体信用卡寄送到您的通讯地址。
# 在此之前如您申请的信用卡支持核发电子卡，我行将同时为您发送电子卡通知短信，您可点击短信中的链接并根据页面指引办理电子信用卡激活。
# 当您收到实体信用卡后，请首先检查卡片正面姓名拼音（英文名）是否正确，经核信息正确后，请在本人的信用卡卡片背面签名栏签名，然后通过以下方式将信用卡激活，以满足您信用卡的

# %%
q1 = "我下个月要出国，可能会临时需要现金。中信信用卡在国外一天最多能拿出多少钱？如果一年里出国很多次，累计有没有限制？"
ra.show(q1, "online")
# Out:
# ...
# [模式:online] Q: 我下个月要出国，可能会临时需要现金。中信信用卡在国外一天最多能拿出多少钱？如果一年里出国很多次，累计有没有限制？
# ------------------------------------------------------------
# A: 根据【业务资料】，您的问题回答如下：
#
# 1. **每日境外取现限额**：每卡每日境外取现额度为**等值1万元人民币**；
# 2. **年度累计限额**：本人名下所有中信银行银行卡（含附属卡）合计，每个自然年度境外取现**不得超过等值10万元人民币**。
#
# 温馨提示：建议境外优先使用信用卡消费支付，更便捷安全；信用卡仅限本人使用，不可出借或借用他人卡片。
# ------------------------------------------------------------
# 召回来源:
#   1. [取现] 根据外汇管理相关规定，持境内卡境外取现的限额为：每卡每日境外取现额度为等值1万元人民币，本人名下银行卡（含附属卡）合计每个自然年度不得超过等...
#   2. [中信银行信用卡章程] 的风险及交易控制指标。第十四条  持卡人若选择以自动转账方式还款，发卡机构有权直接从持卡人提供的个人结算账户中扣款，转入其中信信用卡账户，用...
#   3. [返现规则-出行] 中信银行信运无界信用卡「爱行版」返现规则：全年最高返现1200元，每月最高返现100元。微信/支付宝/云闪付消费返现1%；指定出行商户（如网...
#   4. [返现规则-出行] 中信银行信运无界信用卡「爱行版」返现规则：
# 全年最高返现1200元，每月最高返现100元。
# 微信/支付宝/云闪付消费返现1%；指定出行商户（...

# %%
q2 = "我这个月账单有10000元。如果我到还款日一次性全部还清，和只先还最低还款额，这两种方式在免息、利息和后续还款上有什么区别？"
ra.show(q2, "online")
# Out:
# ...
# [模式:online] Q: 我这个月账单有10000元。如果我到还款日一次性全部还清，和只先还最低还款额，这两种方式在免息、利息和后续还款上有什么区别？
# ------------------------------------------------------------
# A: 根据【业务资料】，两种还款方式的区别如下：
#
# 1. **一次性还清10000元（全额还款）**
#    - ✅ 享受免息还款期待遇（资料2第3条、资料4第二十二条）；
#    - ✅ 本期账单内**非预借现金交易**（如普通消费）不产生任何透支利息；
#    - ❌ 预借现金部分仍不享受免息（但本例未提及预借现金，故不计）；
#    - ✅ 无违约金，信用记录不受影响。
#
# 2. **仅还最低还款额**
#    - ❌ **不享受免息还款期待遇**（资料1第3条、资料2第3条、资料4第二十二条）；
#    - 💰 **全部透支款项自银行记账日起计收透支利息**（含已还部分），日利率0%–0.05%，按月计收复利（资料2第2条）；
#    - ⚠️ 最低还款额计算公式为：
#      `（透支消费本金及相关息费+其它费用）×最低还款比例（2%–15%）+（分期本金+预借现金本金等）×100%+超限款+上期未还最低还款额`（资料1第5条）；
#      → 10000元账单的最低还款额需以当期对账单显示为准，非固定比例；
#    - ❗ 若未还足最低还款额，除利息外，还需支付**最低还款额未还部分5%的违约金**（最低20元）（资料1第5条）；
#    - 📉 剩余未还本金继续计息，利滚利，长期看总成本显著增加。
#
# 总结：全额还款零利息、零违约金；最低还款额将导致**全账单计息（非仅未还部分）+复利+潜在违约金**，且后续每期利息均基于剩余本金滚动计算。
# ------------------------------------------------------------
# 召回来源:
#   1. [第四条 利息与费用] 还款期待遇；乙方预借现金或在免息还款期内未偿还全部欠款的（含最低还款额还款方式），不享受免息还款期待遇，应支付全部透支款项自甲方记账日起至还...
#   2. [第四条 利息与费用] 第四条 利息与费用
# ...

# %%
q3 = "我平时主要有三类支出：吃饭、打车出行、交物业费和水电燃气费。如果我分别选择适合这三类场景的中信信用卡，每个月每类都消费600元，按宣传海报中的返现规则，一个月一共能拿多少返现？连续12个月呢？"
ra.show(q3, "online")
# Out:
# ...
# [模式:online] Q: 我平时主要有三类支出：吃饭、打车出行、交物业费和水电燃气费。如果我分别选择适合这三类场景的中信信用卡，每个月每类都消费600元，按宣传海报中的返现规则，一个月一共能拿多少返现？连续12个月呢？
# ------------------------------------------------------------
# A: 根据资料，您三类支出对应三款不同版本的中信信运无界信用卡，返现规则如下（均适用“每月最高返现100元”上限）：
#
# 1. **吃饭（600元）→ 选「爱吃版」**
#    - 指定美食平台/商户消费返现15%：600 × 15% = 90元
#    - 未超月返现上限100元 → 实际返现 **90元**
#
# 2. **打车出行（600元）→ 选「爱行版」**
#    - 指定出行商户返现15%：600 × 15% = 90元
#    - 未超月返现上限100元 → 实际返现 **90元**
#
# 3. **物业费、水电燃气费（600元）→ 选「爱家版」**
#    - 指定生活缴费返现15%：600 × 15% = 90元
#    - 未超月返现上限100元 → 实际返现 **90元**
#
# ✅ **每月合计返现**：90 + 90 + 90 = **270元**
# ✅ **连续12个月合计返现**：270 × 12 = **3240元**
#
# ⚠️ 注意：
# - 各卡全年返现上限均为1200元（即每卡最多返1200元/年），但您每月每卡仅返90元，12个月为1080元/卡，未达上限，因此可全额兑现。
# - 三卡独立计算，不互相影响。
#
# 结论：
# - 每月返现：**270元**
# - 连续12个月返现：**3240元**
# ------------------------------------------------------------
# 召回来源:
#   1. [返现规则-生活缴费] 中信银行信运无界信用卡「爱家版」返现规则：全年最高返现1200元，每月最高返现100元。微信/支付宝/云闪付消费返现1%；指定商户缴纳物业费...
#   2. [返现规则-生活缴费] 中信银行信运无界信用卡「爱家版」返现规则：
# ...

# %%
for c in ra.CHUNKS:
    if "返现" in c.get("topic", ""):
        print(c["text"][:150])
# Out:
# 中信银行信运无界信用卡「爱吃版」返现规则：
# 全年最高返现1200元，每月最高返现100元。
# 微信/支付宝/云闪付消费返现1%；指定美食平台返现15%；指定美食商户返现15%。
# 适用场景：吃饭、餐饮。首年免年费，交易12笔免次年年费。
# 中信银行信运无界信用卡「爱行版」返现规则：
# 全年最高返现1200元，每月最高返现100元。
# 微信/支付宝/云闪付消费返现1%；指定出行商户（如网约车、打车）返现15%。
# 适用场景：打车出行。首年免年费，交易12笔免次年年费。
# 中信银行信运无界信用卡「爱家版」返现规则：
# 全年最高返现1200元，每月最高返现100元。
# 微信/支付宝/云闪付消费返现1%；指定商户缴纳物业费、电费、燃气费、水费、网费、话费等返现15%。
# 适用场景：物业、水电燃气、生活缴费。首年免年费，交易12笔免次年年费。
# 中信银行信运无界信用卡「爱吃版」返现规则：全年最高返现1200元，每月最高返现100元。微信/支付宝/云闪付消费返现1%；指定美食平台返现15%；指定美食商户返现15%。适用场景：吃饭、餐饮。首年免年费，交易12笔免次年年费。
# 中信银行信运无界信用卡「爱行版」返现规则：全年最高返现1200元，每月最高返现100元。微信/支付宝/云闪付消费返现1%；指定出行商户（如网约车、打车）返现15%。适用场景：打车出行。首年免年费，交易12笔免次年年费。
# 中信银行信运无界信用卡「爱家版」返现规则：全年最高返现1200元，每月最高返现100元。微信/支付宝/云闪付消费返现1%；指定商户缴纳物业费、电费、燃气费、水费、网费、话费等返现15%。适用场景：物业、水电燃气、生活缴费。首年免年费，交易12笔免次年年费。
