# %%
# !D:\anaconda3\envs\rag_env\python.exe rag_assistant.py --mode online "我下个月要出国，可能会临时需要现金。中信信用卡在国外一天最多能拿出多少钱？如果一年里出国很多次，累计有没有限制？"
# Out:
# ...
# [模式:online] Q: 我下个月要出国，可能会临时需要现金。中信信用卡在国外一天最多能拿出多少钱？如果一年里出国很多次，累计有没有限制？
# ------------------------------------------------------------
# A: 根据【业务资料1】：
#
# - 每卡每日境外取现额度为**等值1万元人民币**；
# - 本人名下所有银行卡（含附属卡）合计，每个自然年度境外取现**不得超过等值10万元人民币**。
#
# 温馨提示：建议在境外优先使用信用卡消费支付，而非取现，以保障资金安全与便捷。
# ------------------------------------------------------------
# 召回来源:
#   1. [取现] 根据外汇管理相关规定，持境内卡境外取现的限额为：每卡每日境外取现额度为等值1万元人民币，本人名下银行卡（含附属卡）合计每个自然年度不得超过等...
# Traceback (most recent call last):
#   File "D:\project\citic_credit_rag\rag_assistant.py", line 172, in <module>
#     show(args.question, args.mode)
#   File "D:\project\citic_credit_rag\rag_assistant.py", line 158, in show
#     print(f"  {i+1}. [{c['topic']}] {c['text'][:70]}...")
# UnicodeEncodeError: 'gbk' codec can't encode character '\xa0' in position 32: illegal multibyte sequence

# %%
import sys
sys.path.insert(0, r"D:\project\citic_credit_rag")
from rag_assistant import *  # 看下面的说明

# 问题1
q1 = "我下个月要出国，可能会临时需要现金。中信信用卡在国外一天最多能拿出多少钱？如果一年里出国很多次，累计有没有限制？"
answer1 = ask(q1, mode="online")
print(answer1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sys
#       2 sys.path.insert(0, r"D:\project\citic_credit_rag")
# ----> 3 from rag_assistant import *  # 看下面的说明
#       4
#       5 # 问题1
#       6 q1 = "我下个月要出国，可能会临时需要现金。中信信用卡在国外一天最多能拿出多少钱？如果一年里出国很多次，累计有没有限制？"
#
# File D:\project\citic_credit_rag\rag_assistant.py:20
#       1 # -*- coding: utf-8 -*-
#       2 """
#       3 中信银行信用卡智能咨询助手（RAG 双栈版）
#       4 =================================================
#    (...)     18 生成模型统一用 qwen-plus，保证两栈对比公平。
#      19 """
# ---> 20 import os, json, argparse, pickle, numpy as np, faiss, urllib.request
#      22 # ============ 配置 ============
#      23 BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#
# ModuleNotFoundError: No module named 'faiss'

# %%
import sys
sys.path.insert(0, r"D:\project\citic_credit_rag")
import rag_assistant as ra
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import sys
#       2 sys.path.insert(0, r"D:\project\citic_credit_rag")
# ----> 3 import rag_assistant as ra
#
# File D:\project\citic_credit_rag\rag_assistant.py:20
#       1 # -*- coding: utf-8 -*-
#       2 """
#       3 中信银行信用卡智能咨询助手（RAG 双栈版）
#       4 =================================================
#    (...)     18 生成模型统一用 qwen-plus，保证两栈对比公平。
#      19 """
# ---> 20 import os, json, argparse, pickle, numpy as np, faiss, urllib.request
#      22 # ============ 配置 ============
#      23 BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#
# ModuleNotFoundError: No module named 'faiss'
